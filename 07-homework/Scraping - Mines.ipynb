# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm#MID), thank goodness we can search for these things.

# %% [markdown]
# ## Preparation: Knowing your tags
#
# These questions are the same for every data set, and might not work exactly for yours.
#
# **Search for every operator with 'dirt' in their name, including abandoned mines.**

# %% [markdown]
# ### What is the tag and class name for every row of data?

# %%
# tr

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
# td[2]

# %% [markdown]
# ### What is the tag and class name for every mine's name?

# %%
# td[3]

# %% [markdown]
# ## Being lazy
#
# If you only needed these results, what would you do instead of scraping them?

# %%
# copy-paste into Excel

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Try to scrape the page
#
# To test if you requested the page correctly, save the BeautifulSoup document as `doc` and run the code `doc.find_all('tr')[-1].text` to get the text of the last `<tr>` element.
#
# - If the result starts with **Total Number of Mines Found**, you were successful.

# %%
url = 'https://arlweb.msha.gov/drs/ASP/OprNameStatesearch.asp'

data = {
    'OperSearch': 'dirt',
    'MineName': '',
    'StateSearch': 'None',
    'CM': 'All',
    'x': '47',
    'y': '4',
    'MC': 'Opersearch'
}

response = requests.post(url, data=data)
doc = BeautifulSoup(response.text, 'html.parser')

# %%
doc.find_all('tr')[-1]
# Out:
# <tr>
# <td bgcolor="#000000" colspan="8"><font style="FONT-SIZE:.75em; color:#FFF"><b>Total Number of Mines Found:</b>  <b>129</b></font></td></tr>

# %% [markdown]
# ## Actually scraping

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be your data. What is the index of the first row element that is actually a result?
#
# `.text` will help you here.

# %%
doc.find_all('tr')[7]
# Out:
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3503598"/><font style="FONT-SIZE:.75em;">3503598</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>OR</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --> Newberg Rock &amp; Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Newberg Rock &amp; Dirt<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Crushed, Broken Stone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# Use LIST SLICING to skip the non-data row(s).

# %%
for row in doc.find_all('tr')[7:-1]:
    print(row.find_all('td')[2].text.strip())
# Out:
# Newberg Rock & Dirt
# Allied Dirt Moving Company
# AM Dirtworks & Aggregate Sales
# Atlas-Dirty Devil Mining
# Atlas-Dirty Devil Mining
# Babe's Dirt Work
# Bar-Lin Dirt Company
# Slay'S Dirt Hauling
# Southside Dirt Company
# Spry's Dirt & Gravel, Inc.
# Stewart Dirt Pit
# Stewart Dirt Work, Inc.
# Sweat'S Dirt Hauling Inc
# Toler Roe Dirt Pit
# Tres Palacios Dirt, Sand & Gravel
# Vogt Dirt Service
# Watson Dirt Sand & Gravel Pit Inc
# Y B Dirt & Loam
# Yarbrough Dirt Pit Inc

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
for row in doc.find_all('tr')[7:-1]:
    print(row.find_all('td')[0].text.strip())
# Out:
# 3503598
# 0502030
# 4801789
# 4201449
# 4201450
# 1002257
# 1601167
# 4103265
# 1401575
# 1700776
# 1601251
# 0301963
# 1601082
# 3401751
# 1600916
# 3401211
# 0301267
# 1600956
# 2200033
# 0504953
# 3401929
# 1302445
# 1601106
# 3400915
# 1600983
# 4503200
# 3401266
# 3401468
# 5001797
# 4608254
# 1510279
# 2103723
# 0100776
# 4104016
# 4104757
# 0301729
# 0404851
# 2200734
# 5002028
# 1513393
# 3800602
# 3101630
# 3200860
# 3401762
# 2103517
# 2402626
# 2103181
# 1601124
# 1601150
# 4703427
# 0801306
# 2501216
# 3200965
# 2901371
# 2901544
# 2901709
# 4102355
# 4102420
# 4102869
# 4102951
# 4102958
# 4104876
# 3003502
# 4103258
# 3901432
# 2103556
# 1601250
# 1600908
# 1600953
# 4104185
# 2901536
# 3609624
# 3800709
# 3609931
# 1601257
# 0801275
# 1601379
# 1601380
# 1601381
# 1601134
# 1601165
# 3901042
# 1601194
# 4104054
# 4801674
# 2402474
# 1600920
# 4102955
# 4103107
# 1512530
# 1515619
# 1518318
# 4405366
# 4407196
# 1519685
# 1519799
# 4407003
# 2602570
# 2402503
# 4407296
# 1519273
# 4407270
# 4102682
# 0801259
# 0203332
# 0302015
# 2901986
# 1601127
# 4105017
# 1600986
# 4103324
# 4202013
# 0801371
# 2402115
# 4300748
# 4300768
# 4300776
# 0103209
# 1601159
# 2302283
# 4102586
# 4104475
# 3800617
# 1601234
# 4104648
# 2103518
# 1601292
# 4103429
# 4103264

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.

# %%
mines = []

for mine in doc.find_all('tr')[7:-1]:
    mines.append({
        'Operator ID': mine.find_all('td')[0].text.strip(),
        'Operator name': mine.find_all('td')[2].text.strip(),
        'Mine name': mine.find_all('td')[3].text.strip(),
        'State': mine.find_all('td')[1].text.strip(),
        'Mine type': mine.find_all('td')[4].text.strip(),
        'Coal or metal': mine.find_all('td')[5].text.strip(),
        'Status': mine.find_all('td')[6].text.strip(),
        'Commodity': mine.find_all('td')[7].text.strip(),
    })

# %% [markdown]
# ### Save that to a CSV

# %%
df = pd.DataFrame(mines)
df.to_csv('mines_list.csv', index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
# 9                            BERT'S DIRT    ME          Abandoned
# 10                Big D Dirt Service Inc    LA          Abandoned
# 11                 Big Red Dirt Farm LLC    AR          Abandoned
# 12                    Big River Dirt Pit    LA          Abandoned
# 13           Bob Harris Dirt Contracting    OK          Abandoned
# 14                  Bohannon Sand & Dirt    LA          Abandoned
# 15                Bratcher'S Sand & Dirt    OK          Abandoned
# 16                     Brewer Dirt Works    AR          Abandoned
# 17                       Buck'S Dirt Pit    LA          Abandoned
# 18                    C & G Dirt Hauling    MS          Abandoned
# 19               C N C Dirt Movers, Inc.    NM          Abandoned
# 20    Cambridge Dirt Sand and Gravel LLC    OK          Abandoned
# 21          Central Iowa Dirt & Demo LLC    IA          Abandoned
# 22   Crowes Trucking & Dirt Pit Services    LA          Abandoned
# 23                            D & H Dirt    OK          Abandoned
# 24          Diez Dirt & Sand Hauling Inc    LA          Abandoned
# 25                            Dirt Cheap    WA          Abandoned
# 26                          Dirt Company    OK          Abandoned
# 27                          Dirt Company    OK          Abandoned
# 28                          Dirt Company    AK       Intermittent
# 29                              Dirt Con    WV  Temporarily Idled
# ..                                   ...   ...                ...
# 99                        PB Dirt Movers    VA  Temporarily Idled
# 100                  PB Dirt Movers Inc.    KY          Abandoned
# 101                  PB Dirt Movers, Inc    VA       NonProducing
# 102                      Peveto Dirt Pit    TX          Abandoned
# 103            Phil-Dirt Industries, Inc    FL          Abandoned
# 104                   Prescott Dirt, LLC    AZ       Intermittent
# 105                      R & R Dirtworks    AR          Abandoned
# 106        R D Blankenship Dirt Work LLC    NM             Active
# 107                  Reeves Dirt Pit Inc    LA          Abandoned
# 108                    River Bottom Dirt    TX          Abandoned
# 109                       Roe'S Dirt Pit    LA          Abandoned
# 110        Russell Trest-Dirt Contractor    TX          Abandoned
# 111            S J Stahr Dirt Movers Inc    UT          Abandoned
# 112                  Sand and Dirt, Inc.    FL          Abandoned
# 113             Sierra Rock & Dirt, Inc.    MT          Abandoned
# 114                 Simpson Dirtworx llc    VT          Abandoned
# 115                 SIMPSON DIRTWORX LLC    VT       Intermittent
# 116                 SIMPSON DIRTWORX LLC    VT       Intermittent
# 117                  Slay'S Dirt Hauling    AL          Abandoned
# 118               Southside Dirt Company    LA          Abandoned
# 119           Spry's Dirt & Gravel, Inc.    MO       Intermittent
# 120                     Stewart Dirt Pit    TX          Abandoned
# 121              Stewart Dirt Work, Inc.    TX          Abandoned
# 122             Sweat'S Dirt Hauling Inc    SC          Abandoned
# 123                   Toler Roe Dirt Pit    LA          Abandoned
# 124    Tres Palacios Dirt, Sand & Gravel    TX          Abandoned
# 125                    Vogt Dirt Service    MN       Intermittent
# 126    Watson Dirt Sand & Gravel Pit Inc    LA          Abandoned
# 127                      Y B Dirt & Loam    TX          Abandoned
# 128               Yarbrough Dirt Pit Inc    TX          Abandoned
#
# [129 rows x 8 columns]
