# %% [markdown]
# # Texas Barber Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for barbers in Houson!

# %% [markdown]
# ## Preparation: Knowing your tags
#
# These questions are the same for every data set, and might not work exactly for yours.

# %% [markdown]
# ### What is the tag and class name for every row of data?

# %%
# tr

# %% [markdown]
# ### What is the tag and class name for every person's name?

# %%
# td[0] span[0]

# %% [markdown]
# ### What is the tag and class name for the violation number?

# %%
# td[0] span[-1]

# %% [markdown]
# ### What is the tag and class name for the description of their violation?

# %%
# td[2]

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Try to scrape the page
#
# To test if you requested the page correctly, save the BeautifulSoup document as `doc` and run the code `doc.find_all('tr')[1].text` to get the text of the first `<tr>` element.
#
# - If the result starts with  **nPlease enter at least one (1) parameter** you were NOT successful.
# - If the result starts with **MONTES DE OCA, REINIER**, you were successful.
#
# ### Try to request the page however you think you should.
#
# "Try" to do it, because it *will not work.* Once you've learned that it won't work, you should **ask how to do it on the board**.

# %%
url = 'https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp'

response = requests.post(url)
doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### Try to request the page with the correct data parameters
#
# Secret tip: It still won't work. **Ask why not on the board.**

# %%
url = 'https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp'

data = {
    'pht_status': 'BAR',
    'pht_lic': '',
    'pht_lnm': '',
    'pht_fnm': '',
    'pht_oth_name': '',
    'phy_city': 'HOUSTON',             
    'phy_cnty': '-1',
    'phy_zip': '',
    'B1': 'Search'
}

response = requests.post(url, data=data)
doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### What is the smallest `curl` command that still gives you a result?

# %%
# curl 'https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp' -H 'Referer: https://www.tdlr.texas.gov/cimsfo/' --data 'pht_status=BAR&pht_lic=&pht_lnm=&pht_fnm=&pht_oth_name=&phy_city=HOUSTON+++++++++++++&phy_cnty=-1&phy_zip=&B1=Search'

# %% [markdown]
# ## Request the page with the correct data parameters AND the correct MINIMUM headers
#
# This time it should work.

# %%
url = 'https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp'

data = {
    'pht_status': 'BAR',
    'pht_lic': '',
    'pht_lnm': '',
    'pht_fnm': '',
    'pht_oth_name': '',
    'phy_city': 'HOUSTON',             
    'phy_cnty': '-1',
    'phy_zip': '',
    'B1': 'Search'
}

headers = {
    'Referer': 'https://www.tdlr.texas.gov/cimsfo/'
}

response = requests.post(url, data=data, headers=headers)
doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Loop through each `tr` and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen? I'm happy to help if you ask on the board.

# %%
for row in doc.find_all('tr')[1:]:
    print(row.td.span.text.strip())
# Out:
# MONTES DE OCA, REINIER
# ALFORD, RAYMOND
# CHAPMAN, JESSICA
# SALAZAR-ALVAREZ, SAMUEL
# GONZALES, DAVID
# FLORES, CHRISTOPHER
# ARMSTEAD, CEDRIC J
# MORAH, PATRICK
# TREJO, BLADIMAR A
# DAVIS, RICHARD D
# HOPKINS, JOSHUA
# NINO, ROBERT
# HEATH, LOLETHA N
# SALAZAR-ALVAREZ, SAMUEL
# MONTES DE OCA, REINIER
# Company:
# Company:
# SUTTON, EMANUEL B
# SHEPHARD, JAMES C
# HERNANDEZ, MARIA DIOCELINA
# WILLIAMS, DONTUEL
# JOHNSON, JEFFERY J
# Company:
# HUERTA, FRANCISCO
# TIPTON, SELINA I
# ARREOLA, ERIC D
# HARRISON, OTTO M
# RIVERA TORRES, ANGEL D
# PECK, MARVIN
# MOTA SOTO, CRISTIAN D
# WADDLE, EDDIE D
# SON, YOUNG J
# HILL, BRIAN
# BROWN, DELRICK JAREL
# FRANKLIN, KELVIN
# LEDET, LEON
# WILLIAMS, DONTUEL
# LACY, JUSTIN J
# Company:
# ARELLANO, GREGORY F
# MACEDO, ANTONIO
# MILLER, SHAWN ERIC
# HAYWARD, ABBIE DEAN
# BROWN, CHARLES EARL
# MCQUEEN, IDA M
# MCQUEEN, IDA M
# CAESAR, RON
# MORRIS, VICTOR B
# NOLAN, CHRIS B
# BICKHAM, DONNELL
# LOUIS, DIONNE N
# HARRELL, KENTON D
# SUBRAHMANIAN, CHITRA N
# FRANKLIN, LAWRENCE W
# ADAMS, KERRY
# PATTERSON, RONALD
# LANCASTER, MARLANA DEVONE S
# TOLDEN, REGINALD
# SUTTON, DON C
# Company:
# ALLEN, COURTNEY
# BURTON, VICTOR B
# MOTA SOTO, CRISTIAN D
# LLOYD, BRICE
# Company:
# CANDLEY, LARRY
# RUSSELL, HENRY
# AUTHORLEE, LEROY
# SUTTON, DON C
# THOMAS, NAJO T
# DAVIS, RAY LEE
# SCOTT, ALTON C
# STARKS, MICHAEL J
# SHAFFER, TRACY S
# HILLIARD, OLLIE J
# MOTA SOTO, CRISTIAN D
# CARTER, GEORGE I
# Company:
# Company:
# MOSES, DOROTHY A
# ABREU, VICTOR
# TILLMAN, THOMAS A
# JOULEVETTE, CICELY DENISE
# BAUMAN, QUENTIN
# WHITE, TAYSHA
# GARRISON, BRIAN
# CISNEROS, RHINA
# Company:
# HENRY, TONICE M
# FINGER, DAMON C
# BRITE, STEPHEN
# BRITE, STEPHEN
# SPURLING, CINTHIA
# VASQUEZ, JOSE A
# CARTER, GEORGE I
# JACKSON, STEPHON D
# GRAY, TERRY LEE
# SMALLWOOD, ALDON R
# CAESAR, RON
# Company:
# POTTS, MICKEY
# SUBRAHMANIAN, CHITRA N
# HILL, DE MARCUS W
# ANDERSON, ROSE
# TOM, EKERE COLLINS
# MCCUTCHEON, JAMES
# MAU, SREYLY
# PENNIE, DERRICK L
# CORTEZ, LEON
# BOCARD, ALBERT
# Company:
# GUZMAN, WALTER
# Company:
# ROBERSON, EMIEL R
# DEARMAN, ELMER J
# IKEGBUNAM, OSITA H
# SESSION, MARVIN D
# Company:
# POWELL, MARCUS
# MCPHERSON, REGGIE
# FAISON, TIMOTHY
# GARCIA, JULIO CESAR
# CALLUM, LOURAUN
# COLE, RODERICK B
# TORRES, DAVID LEE
# VILLARREAL, EZEQUIEL P
# WOODS, PRINCE L
# REYES, ROBERTO M
# JONES, ALFRED A
# ABOU ELNAGA, ABDALLA
# TENNESSEE, LEO
# PACHECO, ANA C
# GARCIA, MIGUEL A
# WOOTEN, RODNEY J
# JOHNSON, DAVID P
# PETERS, JONATHAN
# BATES, JEMOND D
# CLARK, RONALD B
# WILLIAMS, ANTHONY K
# REYES, ROBERTO M
# VILLARREAL, EZEQUIEL P
# GARCIA, MIGUEL A
# GILBERT, FRANK A
# Company:
# MCQUEEN, IDA M
# Company:
# BANKS, MICHAEL
# MILLER, GEORGE E
# AYALA, FERNANDO E
# HALL, KEVIN
# NATT, ANGELA D
# GUZMAN, DANIEL A
# HAMDANI, AHMED ABDEL Y
# PRICE, WESLEY D
# ABOU ELNAGA, ABDALLA
# DILLARD, NATHANIEL J
# SUTTON, DON C
# GREEN, MERYKA P
# SANCHEZ, OMAR A
# CLAY, DEVIN L
# ALAGOOL, ASAAD KADHIM A
# HAMDANI, AHMED ABDEL Y
# BOYKIN, BRANDON W
# MEDINA, JENIFER
# METOYER, SHAWN M
# PADRON, ESMERALDA
# WILLIAMS, DERRICK D
# RANDALL, ROGER
# COLLINS, ADRIEL MARCUS
# SHAFFER, ANTHONY
# JOULEVETTE, CICELY DENISE
# SEXTON, BYRON E
# PRUITT, ROBERT LEE
# RUSSELL, HENRY
# RAND, CHARLES

# %% [markdown]
# ## Loop through each `tr`, printing each violation description
#
# - TIP: What is the container tag name for it?
# - TIP: You'll get an error even if you're ALMOST right - which row is causing the problem?

# %%
for row in doc.find_all('tr')[1:]:
    print(row.find_all('td')[2].text.strip())
# Out:
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent failed to electronically submit to the Department at least one time per month student's accrued hours.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent performed barbering without the required license.
# Respondent practiced barbering in an unlicensed facility.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to cooperate with an inspection.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to cooperate with an inspection; Respondent operated a barbershop with an expired license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent is ordered to immediately cease and desist from acting as or impersonating a licensed barber and/or performing or offering to provide barbering services for customers, clients, or the public.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a cosmetology salon with an expired license.
# Respondent operated a barbershop with an expired license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent practiced barbering in an unlicensed facility.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Applicant has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.
# Respondent operated a barbershop with an expired license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent failed to report student hours electronically to the Department at least once per month.
# Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent failed to report student hours electronically to the Department at least once per month.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.
# Respondent operated a barbershop without holding the appropriate license.
# Respondent performed barbering with an expired license.
# Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Applicant has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation; Applicant has been convicted of a crime that was committed within 5 years of his application.
# Respondent failed to properly clean and disinfect hair cutting, styling and treatment equipment, implements, tools and materials; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent performed barbering without the required license.
# Respondent failed to provide a student who had enrolled in school a copy of the refund policy.
# Respondent performed barbering with an expired license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent left applicators standing in the wax. Respondent failed to apply for a new salon license within thirty (30) days of a change of ownership.
# Respondent performed barbering with an expired license.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to submit a student's accrued hours once per month; Respondent failed to make available for Department review monthly progress reports and daily attendance records for a student.
# Respondent practiced barbering in an unlicensed facility.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent performed barbering without the required license.
# Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.
# Respondent is assessed an administrative penalty in the amount of $
# Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent allowed a student on the premises who was not wearing a smock.
# Respondent performed barbering without the required license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent failed to have a container of liquid disinfectant at each barber station; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent performed barbering without the required license.
# Applicant lacks sufficient honesty, trustworthiness and integrity to hold a license; Applicant has been convicted of a crime that was committed within 5 years of his application.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent performed barbering with an expired license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed of a barber establishment owner, manager, or their representative to cooperate with an inspector in the performance of the inspection.
# Respondent failed to properly account for hours granted to each student.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# Respondent failed to obtain a new permit within 30 days following the transfer of ownership; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to obtain a new permit within 30 days following the transfer of ownership; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a barbershop with an expired license; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent possessed or used of fumigants such as formalin (formaldehyde) tablets or liquids.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.
# Respondent leased space in a barber shop to multiple individuals who engaged in the practice of barbering but had not obtained a barber license; Respondent operated a barbershop without holding the appropriate license; Respondent failed to have a container of liquid disinfectant located at each barber chair or station; Respondent's hand washing facilities failed to include hot and cold running water.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent practiced barbering in an unlicensed facility.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent decreased hours earned by students in their school records.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent operated a barbershop with an expired license.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent operated a barbershop without holding the appropriate license.
# Respondent practiced barbering in an unlicensed facility.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondents failed to obtain a new license after the shop moved.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent left applicators standing in the wax.
# Respondent performed barbering without the required license.
# Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation; Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history.
# Respondent operated a barbershop without holding the appropriate license; Respondent performed barbering without the required license.
# Respondent failed to comply with an order previously issued by the Executive Director.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to have a container of liquid disinfectant located at each barber chair or station; Respondent failed to disinfect shampoo bowls and manicure tables prior to use for each client.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent failed to comply with an order previously issued by the Executive Director; Respondent performed barbering with an expired license.
# Respondent operated a barbershop without holding the appropriate license.
# Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# Respondent operated a barbershop with an expired license; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.
# Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent performed barbering without the required license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to multiple individuals who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to submit to the Department an electronic record of each student's accrued hours; Respondent increased credit hours earned to multiple students.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent failed to have hand washing facility with hot running water.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent performed barbering without the required license.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.
# Respondent performed barbering without the required license.
# Respondent performed barbering with an expired license.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Applicant lacks sufficient honesty, trustworthiness and integrity to hold a license; Applicant has been convicted of a crime that was committed within 5 years of his application.
# Respondent performed barbering with an expired license.
# Respondent operated a barbershop without holding the appropriate license; Respondent performed barbering without the required license.

# %% [markdown]
# ## Loop through each `tr`, printing the complaint number
#
# - TIP: It should be the last piece of the fist `td`

# %%
for row in doc.find_all('tr')[1:]:
    print(row.td.find_all('span')[-1].text.strip())
# Out:
# BAR20170009735
# BAR20170013061
# BAR20160014463
# BAR20170009706
# BAR20160024898
# BAR20170003858
# BAR20170017750
# BAR20170001067
# BAR20170015712
# BAR20160026976
# BAR20170004945
# BAR20170005752
# BAR20170008862
# BAR20170009706
# BAR20170009735
# BAR20170010211
# BAR20170015711
# BAR20170005607
# BAR20170012408
# BAR20160015455
# BAR20170004000
# BAR20170004622
# BAR20170009953
# BAR20160019178
# BAR20170003998
# BAR20170005585
# BAR20170004247
# BAR20170004644
# BAR20170001084
# BAR20170003233
# BAR20170007267
# BAR20170004607
# BAR20170004726
# BAR20170000258
# BAR20170000872
# BAR20170000888
# BAR20170004000
# BAR20170001296
# BAR20170001765
# BAR20160000930
# BAR20160012081
# BAR20160023793
# BAR20160020239
# BAR20160025221
# BAR20160003560
# BAR20160014501
# BAR20160020292
# BAR20160019711
# BAR20160020884
# BAR20160013209
# BAR20160013204
# BAR20160013487
# BAR20160020715
# BAR20150023440
# BAR20160015167
# BAR20160010384
# BAR20160010595
# BAR20160010403
# BAR20160003712
# BAR20160002891
# BAR20160006458
# BAR20160017201
# BAR20160005691
# BAR20160012167
# BAR20160010137
# BAR20150016373
# BAR20150020574
# BAR20160011498
# BAR20150022763
# BAR20150024251
# BAR20150014628
# BAR20150016869
# BAR20150005142
# BAR20160000710
# BAR20160003580
# BAR20150020772
# BAR20150022808
# BAR20150012542
# BAR20150020936
# BAR20160006057
# BAR20150020900
# BAR20140020322
# BAR20150023686
# BAR20160002257
# BAR20160006283
# BAR20150015351
# BAR20150017189
# BAR20160003552
# BAR20150016865
# BAR20150003948
# BAR20140012731
# BAR20150015995
# BAR20140013044
# BAR20150021856
# BAR20150022808
# BAR20160001941
# BAR20150015119
# BAR20150020299
# BAR20140019723
# BAR20150020936
# BAR20150020943
# BAR20150008887
# BAR20150010286
# BAR20150015346
# BAR20150008529
# BAR20150020726
# BAR20150011280
# BAR20150014646
# BAR20150016885
# BAR20150012508
# BAR20140004827
# BAR20150007016
# BAR20150009370
# BAR20150004210
# BAR20150013309
# BAR20140001295
# BAR20140020206
# BAR20150012542
# BAR20150012580
# BAR20140008929
# BAR20150014662
# BAR20140016309
# BAR20150013794
# BAR20150013147
# BAR20150009264
# BAR20140005542
# BAR20150003439
# BAR20140005541
# BAR20150003945
# BAR20150006308
# BAR20150010343
# BAR20150007310
# BAR20140005543
# BAR20140011649
# BAR20140001139
# BAR20140019446
# BAR20150009491
# BAR20150001429
# BAR20150008390
# BAR20140005541
# BAR20140005542
# BAR20140005543
# BAR20140008927
# BAR20140017760
# BAR20140002728
# BAR20150003987
# BAR20120020318
# BAR20150006331
# BAR20150007314
# BAR20150004544
# BAR20130015774
# BAR20140014935
# BAR20150002030
# BAR20150005628
# BAR20150002028
# BAR20150003768
# BAR20140018349
# BAR20150000367
# BAR20130018669
# BAR20150002894
# BAR20150002029
# BAR20150002030
# BAR20140006139
# BAR20140016318
# BAR20140017873
# BAR20140017648
# BAR20140019563
# BAR20140006135
# BAR20140007767
# BAR20130019444
# BAR20140001969
# BAR20140017962
# BAR20140010225
# BAR20120016389
# BAR20130014676

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
#
# Create a new dictionary for each `tr` (except the header).

# %%
violations = []

for violation in doc.find_all('tr')[1:]:
    violations.append({
        'name': violation.td.span.text.strip(),
        'description': violation.find_all('td')[2].text.strip(),
        'number': violation.td.find_all('span')[-1].text.strip()
    })

violations
# Out:
# [{'description': 'Respondent performed barbering without the required license.',
#   'name': 'MONTES DE OCA, REINIER',
#   'number': 'BAR20170009735'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'ALFORD, RAYMOND',
#   'number': 'BAR20170013061'},
#  {'description': "Respondent failed to electronically submit to the Department at least one time per month student's accrued hours.",
#   'name': 'CHAPMAN, JESSICA',
#   'number': 'BAR20160014463'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'SALAZAR-ALVAREZ, SAMUEL',
#   'number': 'BAR20170009706'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'GONZALES, DAVID',
#   'number': 'BAR20160024898'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'FLORES, CHRISTOPHER',
#   'number': 'BAR20170003858'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'ARMSTEAD, CEDRIC J',
#   'number': 'BAR20170017750'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'name': 'MORAH, PATRICK',
#   'number': 'BAR20170001067'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'TREJO, BLADIMAR A',
#   'number': 'BAR20170015712'},
#  {'description': 'Respondent practiced barbering in an unlicensed facility.',
#   'name': 'DAVIS, RICHARD D',
#   'number': 'BAR20160026976'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'HOPKINS, JOSHUA',
#   'number': 'BAR20170004945'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'NINO, ROBERT',
#   'number': 'BAR20170005752'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'HEATH, LOLETHA N',
#   'number': 'BAR20170008862'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'SALAZAR-ALVAREZ, SAMUEL',
#   'number': 'BAR20170009706'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'MONTES DE OCA, REINIER',
#   'number': 'BAR20170009735'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'Company:',
#   'number': 'BAR20170010211'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'Company:',
#   'number': 'BAR20170015711'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'SUTTON, EMANUEL B',
#   'number': 'BAR20170005607'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'SHEPHARD, JAMES C',
#   'number': 'BAR20170012408'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to cooperate with an inspection.',
#   'name': 'HERNANDEZ, MARIA DIOCELINA',
#   'number': 'BAR20160015455'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'WILLIAMS, DONTUEL',
#   'number': 'BAR20170004000'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'JOHNSON, JEFFERY J',
#   'number': 'BAR20170004622'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'Company:',
#   'number': 'BAR20170009953'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to cooperate with an inspection; Respondent operated a barbershop with an expired license.',
#   'name': 'HUERTA, FRANCISCO',
#   'number': 'BAR20160019178'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'TIPTON, SELINA I',
#   'number': 'BAR20170003998'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'ARREOLA, ERIC D',
#   'number': 'BAR20170005585'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'HARRISON, OTTO M',
#   'number': 'BAR20170004247'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'RIVERA TORRES, ANGEL D',
#   'number': 'BAR20170004644'},
#  {'description': 'Respondent is ordered to immediately cease and desist from acting as or impersonating a licensed barber and/or performing or offering to provide barbering services for customers, clients, or the public.',
#   'name': 'PECK, MARVIN',
#   'number': 'BAR20170001084'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'MOTA SOTO, CRISTIAN D',
#   'number': 'BAR20170003233'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'WADDLE, EDDIE D',
#   'number': 'BAR20170007267'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'SON, YOUNG J',
#   'number': 'BAR20170004607'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'HILL, BRIAN',
#   'number': 'BAR20170004726'},
#  {'description': 'Respondent operated a cosmetology salon with an expired license.',
#   'name': 'BROWN, DELRICK JAREL',
#   'number': 'BAR20170000258'},
#  {'description': 'Respondent operated a barbershop with an expired license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'name': 'FRANKLIN, KELVIN',
#   'number': 'BAR20170000872'},
#  {'description': 'Respondent practiced barbering in an unlicensed facility.',
#   'name': 'LEDET, LEON',
#   'number': 'BAR20170000888'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'WILLIAMS, DONTUEL',
#   'number': 'BAR20170004000'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'LACY, JUSTIN J',
#   'number': 'BAR20170001296'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'Company:',
#   'number': 'BAR20170001765'},
#  {'description': 'Applicant has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.',
#   'name': 'ARELLANO, GREGORY F',
#   'number': 'BAR20160000930'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'MACEDO, ANTONIO',
#   'number': 'BAR20160012081'},
#  {'description': 'Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.',
#   'name': 'MILLER, SHAWN ERIC',
#   'number': 'BAR20160023793'},
#  {'description': 'Respondent operated a barbershop with an expired license.',
#   'name': 'HAYWARD, ABBIE DEAN',
#   'number': 'BAR20160020239'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'BROWN, CHARLES EARL',
#   'number': 'BAR20160025221'},
#  {'description': "Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent failed to report student hours electronically to the Department at least once per month.",
#   'name': 'MCQUEEN, IDA M',
#   'number': 'BAR20160003560'},
#  {'description': "Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent failed to report student hours electronically to the Department at least once per month.",
#   'name': 'MCQUEEN, IDA M',
#   'number': 'BAR20160014501'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'CAESAR, RON',
#   'number': 'BAR20160020292'},
#  {'description': 'Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.',
#   'name': 'MORRIS, VICTOR B',
#   'number': 'BAR20160019711'},
#  {'description': 'Respondent operated a barbershop without holding the appropriate license.',
#   'name': 'NOLAN, CHRIS B',
#   'number': 'BAR20160020884'},
#  {'description': 'Respondent performed barbering with an expired license.',
#   'name': 'BICKHAM, DONNELL',
#   'number': 'BAR20160013209'},
#  {'description': 'Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'LOUIS, DIONNE N',
#   'number': 'BAR20160013204'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'HARRELL, KENTON D',
#   'number': 'BAR20160013487'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'SUBRAHMANIAN, CHITRA N',
#   'number': 'BAR20160020715'},
#  {'description': 'Applicant has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation; Applicant has been convicted of a crime that was committed within 5 years of his application.',
#   'name': 'FRANKLIN, LAWRENCE W',
#   'number': 'BAR20150023440'},
#  {'description': 'Respondent failed to properly clean and disinfect hair cutting, styling and treatment equipment, implements, tools and materials; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.',
#   'name': 'ADAMS, KERRY',
#   'number': 'BAR20160015167'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'PATTERSON, RONALD',
#   'number': 'BAR20160010384'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'LANCASTER, MARLANA DEVONE S',
#   'number': 'BAR20160010595'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'TOLDEN, REGINALD',
#   'number': 'BAR20160010403'},
#  {'description': 'Respondent failed to provide a student who had enrolled in school a copy of the refund policy.',
#   'name': 'SUTTON, DON C',
#   'number': 'BAR20160003712'},
#  {'description': 'Respondent performed barbering with an expired license.',
#   'name': 'Company:',
#   'number': 'BAR20160002891'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'ALLEN, COURTNEY',
#   'number': 'BAR20160006458'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'BURTON, VICTOR B',
#   'number': 'BAR20160017201'},
#  {'description': 'Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'MOTA SOTO, CRISTIAN D',
#   'number': 'BAR20160005691'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'LLOYD, BRICE',
#   'number': 'BAR20160012167'},
#  {'description': 'Respondent left applicators standing in the wax. Respondent failed to apply for a new salon license within thirty (30) days of a change of ownership.',
#   'name': 'Company:',
#   'number': 'BAR20160010137'},
#  {'description': 'Respondent performed barbering with an expired license.',
#   'name': 'CANDLEY, LARRY',
#   'number': 'BAR20150016373'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'RUSSELL, HENRY',
#   'number': 'BAR20150020574'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'AUTHORLEE, LEROY',
#   'number': 'BAR20160011498'},
#  {'description': "Respondent failed to submit a student's accrued hours once per month; Respondent failed to make available for Department review monthly progress reports and daily attendance records for a student.",
#   'name': 'SUTTON, DON C',
#   'number': 'BAR20150022763'},
#  {'description': 'Respondent practiced barbering in an unlicensed facility.',
#   'name': 'THOMAS, NAJO T',
#   'number': 'BAR20150024251'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'DAVIS, RAY LEE',
#   'number': 'BAR20150014628'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'SCOTT, ALTON C',
#   'number': 'BAR20150016869'},
#  {'description': 'Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client.',
#   'name': 'STARKS, MICHAEL J',
#   'number': 'BAR20150005142'},
#  {'description': 'Respondent is assessed an administrative penalty in the amount of $',
#   'name': 'SHAFFER, TRACY S',
#   'number': 'BAR20160000710'},
#  {'description': "Respondent failed to electronically submit a student's withdrawal or termination to the Department within 10 days; Respondent allowed a student on the premises who was not wearing a smock.",
#   'name': 'HILLIARD, OLLIE J',
#   'number': 'BAR20160003580'},
#  {'description': 'Respondent performed barbering without the required license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'name': 'MOTA SOTO, CRISTIAN D',
#   'number': 'BAR20150020772'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'CARTER, GEORGE I',
#   'number': 'BAR20150022808'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'Company:',
#   'number': 'BAR20150012542'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'Company:',
#   'number': 'BAR20150020936'},
#  {'description': 'Respondent failed to have a container of liquid disinfectant at each barber station; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'name': 'MOSES, DOROTHY A',
#   'number': 'BAR20160006057'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'ABREU, VICTOR',
#   'number': 'BAR20150020900'},
#  {'description': 'Applicant lacks sufficient honesty, trustworthiness and integrity to hold a license; Applicant has been convicted of a crime that was committed within 5 years of his application.',
#   'name': 'TILLMAN, THOMAS A',
#   'number': 'BAR20140020322'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'JOULEVETTE, CICELY DENISE',
#   'number': 'BAR20150023686'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'BAUMAN, QUENTIN',
#   'number': 'BAR20160002257'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'WHITE, TAYSHA',
#   'number': 'BAR20160006283'},
#  {'description': 'Respondent performed barbering with an expired license.',
#   'name': 'GARRISON, BRIAN',
#   'number': 'BAR20150015351'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed of a barber establishment owner, manager, or their representative to cooperate with an inspector in the performance of the inspection.',
#   'name': 'CISNEROS, RHINA',
#   'number': 'BAR20150017189'},
#  {'description': 'Respondent failed to properly account for hours granted to each student.',
#   'name': 'Company:',
#   'number': 'BAR20160003552'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'HENRY, TONICE M',
#   'number': 'BAR20150016865'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'FINGER, DAMON C',
#   'number': 'BAR20150003948'},
#  {'description': 'Respondent failed to obtain a new permit within 30 days following the transfer of ownership; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'name': 'BRITE, STEPHEN',
#   'number': 'BAR20140012731'},
#  {'description': 'Respondent failed to obtain a new permit within 30 days following the transfer of ownership; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'name': 'BRITE, STEPHEN',
#   'number': 'BAR20150015995'},
#  {'description': 'Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.',
#   'name': 'SPURLING, CINTHIA',
#   'number': 'BAR20140013044'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'VASQUEZ, JOSE A',
#   'number': 'BAR20150021856'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'CARTER, GEORGE I',
#   'number': 'BAR20150022808'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'JACKSON, STEPHON D',
#   'number': 'BAR20160001941'},
#  {'description': 'Respondent operated a barbershop with an expired license; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'name': 'GRAY, TERRY LEE',
#   'number': 'BAR20150015119'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'SMALLWOOD, ALDON R',
#   'number': 'BAR20150020299'},
#  {'description': 'Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'CAESAR, RON',
#   'number': 'BAR20140019723'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'Company:',
#   'number': 'BAR20150020936'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'POTTS, MICKEY',
#   'number': 'BAR20150020943'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'SUBRAHMANIAN, CHITRA N',
#   'number': 'BAR20150008887'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'HILL, DE MARCUS W',
#   'number': 'BAR20150010286'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'ANDERSON, ROSE',
#   'number': 'BAR20150015346'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'TOM, EKERE COLLINS',
#   'number': 'BAR20150008529'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'MCCUTCHEON, JAMES',
#   'number': 'BAR20150020726'},
#  {'description': 'Respondent possessed or used of fumigants such as formalin (formaldehyde) tablets or liquids.',
#   'name': 'MAU, SREYLY',
#   'number': 'BAR20150011280'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'PENNIE, DERRICK L',
#   'number': 'BAR20150014646'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'CORTEZ, LEON',
#   'number': 'BAR20150016885'},
#  {'description': 'Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements.',
#   'name': 'BOCARD, ALBERT',
#   'number': 'BAR20150012508'},
#  {'description': "Respondent leased space in a barber shop to multiple individuals who engaged in the practice of barbering but had not obtained a barber license; Respondent operated a barbershop without holding the appropriate license; Respondent failed to have a container of liquid disinfectant located at each barber chair or station; Respondent's hand washing facilities failed to include hot and cold running water.",
#   'name': 'Company:',
#   'number': 'BAR20140004827'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'GUZMAN, WALTER',
#   'number': 'BAR20150007016'},
#  {'description': 'Respondent practiced barbering in an unlicensed facility.',
#   'name': 'Company:',
#   'number': 'BAR20150009370'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'ROBERSON, EMIEL R',
#   'number': 'BAR20150004210'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'DEARMAN, ELMER J',
#   'number': 'BAR20150013309'},
#  {'description': 'Respondent decreased hours earned by students in their school records.',
#   'name': 'IKEGBUNAM, OSITA H',
#   'number': 'BAR20140001295'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent operated a barbershop with an expired license.',
#   'name': 'SESSION, MARVIN D',
#   'number': 'BAR20140020206'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'Company:',
#   'number': 'BAR20150012542'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'POWELL, MARCUS',
#   'number': 'BAR20150012580'},
#  {'description': 'Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.',
#   'name': 'MCPHERSON, REGGIE',
#   'number': 'BAR20140008929'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'FAISON, TIMOTHY',
#   'number': 'BAR20150014662'},
#  {'description': 'Respondent operated a barbershop without holding the appropriate license.',
#   'name': 'GARCIA, JULIO CESAR',
#   'number': 'BAR20140016309'},
#  {'description': 'Respondent practiced barbering in an unlicensed facility.',
#   'name': 'CALLUM, LOURAUN',
#   'number': 'BAR20150013794'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'COLE, RODERICK B',
#   'number': 'BAR20150013147'},
#  {'description': 'Respondents failed to obtain a new license after the shop moved.',
#   'name': 'TORRES, DAVID LEE',
#   'number': 'BAR20150009264'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'VILLARREAL, EZEQUIEL P',
#   'number': 'BAR20140005542'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering with an expired barber license.',
#   'name': 'WOODS, PRINCE L',
#   'number': 'BAR20150003439'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'REYES, ROBERTO M',
#   'number': 'BAR20140005541'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license; Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.',
#   'name': 'JONES, ALFRED A',
#   'number': 'BAR20150003945'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'ABOU ELNAGA, ABDALLA',
#   'number': 'BAR20150006308'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'TENNESSEE, LEO',
#   'number': 'BAR20150010343'},
#  {'description': 'Respondent left applicators standing in the wax.',
#   'name': 'PACHECO, ANA C',
#   'number': 'BAR20150007310'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'GARCIA, MIGUEL A',
#   'number': 'BAR20140005543'},
#  {'description': "Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation; Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history.",
#   'name': 'WOOTEN, RODNEY J',
#   'number': 'BAR20140011649'},
#  {'description': 'Respondent operated a barbershop without holding the appropriate license; Respondent performed barbering without the required license.',
#   'name': 'JOHNSON, DAVID P',
#   'number': 'BAR20140001139'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'PETERS, JONATHAN',
#   'number': 'BAR20140019446'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'BATES, JEMOND D',
#   'number': 'BAR20150009491'},
#  {'description': 'Respondent failed to have a container of liquid disinfectant located at each barber chair or station; Respondent failed to disinfect shampoo bowls and manicure tables prior to use for each client.',
#   'name': 'CLARK, RONALD B',
#   'number': 'BAR20150001429'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'WILLIAMS, ANTHONY K',
#   'number': 'BAR20150008390'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'REYES, ROBERTO M',
#   'number': 'BAR20140005541'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'VILLARREAL, EZEQUIEL P',
#   'number': 'BAR20140005542'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'GARCIA, MIGUEL A',
#   'number': 'BAR20140005543'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director; Respondent performed barbering with an expired license.',
#   'name': 'GILBERT, FRANK A',
#   'number': 'BAR20140008927'},
#  {'description': 'Respondent operated a barbershop without holding the appropriate license.',
#   'name': 'Company:',
#   'number': 'BAR20140017760'},
#  {'description': 'Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.',
#   'name': 'MCQUEEN, IDA M',
#   'number': 'BAR20140002728'},
#  {'description': 'Respondent operated a barbershop with an expired license; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'name': 'Company:',
#   'number': 'BAR20150003987'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'BANKS, MICHAEL',
#   'number': 'BAR20120020318'},
#  {'description': 'Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.',
#   'name': 'MILLER, GEORGE E',
#   'number': 'BAR20150006331'},
#  {'description': 'Respondent failed to prepare fresh disinfectant solution in accordance with Department regulations.',
#   'name': 'AYALA, FERNANDO E',
#   'number': 'BAR20150007314'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'HALL, KEVIN',
#   'number': 'BAR20150004544'},
#  {'description': 'Respondent failed to clean required implements and spray with either an EPA-registered disinfectant, alcohol, or bleach solution after each client; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair.',
#   'name': 'NATT, ANGELA D',
#   'number': 'BAR20130015774'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'GUZMAN, DANIEL A',
#   'number': 'BAR20140014935'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'HAMDANI, AHMED ABDEL Y',
#   'number': 'BAR20150002030'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'PRICE, WESLEY D',
#   'number': 'BAR20150005628'},
#  {'description': 'Respondent leased space in a barber shop to multiple individuals who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'ABOU ELNAGA, ABDALLA',
#   'number': 'BAR20150002028'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'DILLARD, NATHANIEL J',
#   'number': 'BAR20150003768'},
#  {'description': "Respondent failed to submit to the Department an electronic record of each student's accrued hours; Respondent increased credit hours earned to multiple students.",
#   'name': 'SUTTON, DON C',
#   'number': 'BAR20140018349'},
#  {'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'name': 'GREEN, MERYKA P',
#   'number': 'BAR20150000367'},
#  {'description': 'Respondent failed to have hand washing facility with hot running water.',
#   'name': 'SANCHEZ, OMAR A',
#   'number': 'BAR20130018669'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'CLAY, DEVIN L',
#   'number': 'BAR20150002894'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'ALAGOOL, ASAAD KADHIM A',
#   'number': 'BAR20150002029'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'HAMDANI, AHMED ABDEL Y',
#   'number': 'BAR20150002030'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'BOYKIN, BRANDON W',
#   'number': 'BAR20140006139'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'MEDINA, JENIFER',
#   'number': 'BAR20140016318'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'METOYER, SHAWN M',
#   'number': 'BAR20140017873'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'PADRON, ESMERALDA',
#   'number': 'BAR20140017648'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'WILLIAMS, DERRICK D',
#   'number': 'BAR20140019563'},
#  {'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'RANDALL, ROGER',
#   'number': 'BAR20140006135'},
#  {'description': 'Respondent operated a barbershop with an expired license; Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'name': 'COLLINS, ADRIEL MARCUS',
#   'number': 'BAR20140007767'},
#  {'description': 'Respondent performed barbering without the required license.',
#   'name': 'SHAFFER, ANTHONY',
#   'number': 'BAR20130019444'},
#  {'description': 'Respondent performed barbering with an expired license.',
#   'name': 'JOULEVETTE, CICELY DENISE',
#   'number': 'BAR20140001969'},
#  {'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'name': 'SEXTON, BYRON E',
#   'number': 'BAR20140017962'},
#  {'description': 'Applicant lacks sufficient honesty, trustworthiness and integrity to hold a license; Applicant has been convicted of a crime that was committed within 5 years of his application.',
#   'name': 'PRUITT, ROBERT LEE',
#   'number': 'BAR20140010225'},
#  {'description': 'Respondent performed barbering with an expired license.',
#   'name': 'RUSSELL, HENRY',
#   'number': 'BAR20120016389'},
#  {'description': 'Respondent operated a barbershop without holding the appropriate license; Respondent performed barbering without the required license.',
#   'name': 'RAND, CHARLES',
#   'number': 'BAR20130014676'}]

# %% [markdown]
# ### Save that to a CSV

# %%
df = pd.DataFrame(violations)
df.to_csv('violations.csv', index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv('violations.csv')
# Out:
#                                            description  \
# 0    Respondent performed barbering without the req...
# 1    Respondent performed barbering without the req...
# 2    Respondent failed to electronically submit to ...
# 3    Respondent performed barbering without the req...
# 4    Respondent leased space in a barber shop to an...
# 5    Respondent leased space in a barber shop to an...
# 6    The Respondent's license was revoked upon Resp...
# 7    Respondent leased space in a barber shop to an...
# 8    Respondent performed barbering without the req...
# 9    Respondent practiced barbering in an unlicense...
# 10   Respondent performed barbering without the req...
# 11   Respondent performed barbering without the req...
# 12   Respondent leased space in a barber shop to an...
# 13   Respondent performed barbering without the req...
# 14   Respondent performed barbering without the req...
# 15   Respondent performed barbering without the req...
# 16   Respondent performed barbering without the req...
# 17   Respondent performed barbering without the req...
# 18   The Respondent's license was revoked upon Resp...
# 19   Respondent leased space in a barber shop to an...
# 20   Respondent performed barbering without the req...
# 21   Respondent performed barbering without the req...
# 22   Respondent performed barbering without the req...
# 23   Respondent leased space in a barber shop to an...
# 24   Respondent leased space in a barber shop to an...
# 25   Respondent leased space in a barber shop to an...
# 26   Respondent performed barbering without the req...
# 27   Respondent performed barbering without the req...
# 28   Respondent is ordered to immediately cease and...
# 29   Respondent failed to comply with an order prev...
# ..                                                 ...
# 145  Respondent operated a barbershop with an expir...
# 146  Respondent failed to comply with an order prev...
# 147  Respondent failed to prepare fresh disinfectan...
# 148  Respondent failed to prepare fresh disinfectan...
# 149  The Respondent's license was revoked upon Resp...
# 150  Respondent failed to clean required implements...
# 151  Respondent failed to comply with an order prev...
# 152  Respondent performed barbering without the req...
# 153  The Respondent's license was revoked upon Resp...
# 154  Respondent leased space in a barber shop to mu...
# 155  The Respondent's license was revoked upon Resp...
# 156  Respondent failed to submit to the Department ...
# 157  Respondent failed to comply with an order prev...
# 158  Respondent failed to have hand washing facilit...
# 159  The Respondent's license was revoked upon Resp...
# 160  Respondent performed barbering without the req...
# 161  Respondent performed barbering without the req...
# 162  Respondent performed barbering without the req...
# 163  Respondent leased space in a barber shop to an...
# 164  The Respondent's license was revoked upon Resp...
# 165  Respondent leased space in a barber shop to an...
# 166  The Respondent's license was revoked upon Resp...
# 167  Respondent leased space in a barber shop to an...
# 168  Respondent operated a barbershop with an expir...
# 169  Respondent performed barbering without the req...
# 170  Respondent performed barbering with an expired...
# 171  The Respondent's license was revoked upon Resp...
# 172  Applicant lacks sufficient honesty, trustworth...
# 173  Respondent performed barbering with an expired...
# 174  Respondent operated a barbershop without holdi...
#
#                            name          number
# 0        MONTES DE OCA, REINIER  BAR20170009735
# 1               ALFORD, RAYMOND  BAR20170013061
# 2              CHAPMAN, JESSICA  BAR20160014463
# 3       SALAZAR-ALVAREZ, SAMUEL  BAR20170009706
# 4               GONZALES, DAVID  BAR20160024898
# 5           FLORES, CHRISTOPHER  BAR20170003858
# 6            ARMSTEAD, CEDRIC J  BAR20170017750
# 7                MORAH, PATRICK  BAR20170001067
# 8             TREJO, BLADIMAR A  BAR20170015712
# 9              DAVIS, RICHARD D  BAR20160026976
# 10              HOPKINS, JOSHUA  BAR20170004945
# 11                 NINO, ROBERT  BAR20170005752
# 12             HEATH, LOLETHA N  BAR20170008862
# 13      SALAZAR-ALVAREZ, SAMUEL  BAR20170009706
# 14       MONTES DE OCA, REINIER  BAR20170009735
# 15                     Company:  BAR20170010211
# 16                     Company:  BAR20170015711
# 17            SUTTON, EMANUEL B  BAR20170005607
# 18            SHEPHARD, JAMES C  BAR20170012408
# 19   HERNANDEZ, MARIA DIOCELINA  BAR20160015455
# 20            WILLIAMS, DONTUEL  BAR20170004000
# 21           JOHNSON, JEFFERY J  BAR20170004622
# 22                     Company:  BAR20170009953
# 23            HUERTA, FRANCISCO  BAR20160019178
# 24             TIPTON, SELINA I  BAR20170003998
# 25              ARREOLA, ERIC D  BAR20170005585
# 26             HARRISON, OTTO M  BAR20170004247
# 27       RIVERA TORRES, ANGEL D  BAR20170004644
# 28                 PECK, MARVIN  BAR20170001084
# 29        MOTA SOTO, CRISTIAN D  BAR20170003233
# ..                          ...             ...
# 145                    Company:  BAR20150003987
# 146              BANKS, MICHAEL  BAR20120020318
# 147            MILLER, GEORGE E  BAR20150006331
# 148           AYALA, FERNANDO E  BAR20150007314
# 149                 HALL, KEVIN  BAR20150004544
# 150              NATT, ANGELA D  BAR20130015774
# 151            GUZMAN, DANIEL A  BAR20140014935
# 152      HAMDANI, AHMED ABDEL Y  BAR20150002030
# 153             PRICE, WESLEY D  BAR20150005628
# 154        ABOU ELNAGA, ABDALLA  BAR20150002028
# 155        DILLARD, NATHANIEL J  BAR20150003768
# 156               SUTTON, DON C  BAR20140018349
# 157             GREEN, MERYKA P  BAR20150000367
# 158             SANCHEZ, OMAR A  BAR20130018669
# 159               CLAY, DEVIN L  BAR20150002894
# 160     ALAGOOL, ASAAD KADHIM A  BAR20150002029
# 161      HAMDANI, AHMED ABDEL Y  BAR20150002030
# 162           BOYKIN, BRANDON W  BAR20140006139
# 163             MEDINA, JENIFER  BAR20140016318
# 164            METOYER, SHAWN M  BAR20140017873
# 165           PADRON, ESMERALDA  BAR20140017648
# 166         WILLIAMS, DERRICK D  BAR20140019563
# 167              RANDALL, ROGER  BAR20140006135
# 168      COLLINS, ADRIEL MARCUS  BAR20140007767
# 169            SHAFFER, ANTHONY  BAR20130019444
# 170   JOULEVETTE, CICELY DENISE  BAR20140001969
# 171             SEXTON, BYRON E  BAR20140017962
# 172          PRUITT, ROBERT LEE  BAR20140010225
# 173              RUSSELL, HENRY  BAR20120016389
# 174               RAND, CHARLES  BAR20130014676
#
# [175 rows x 3 columns]
